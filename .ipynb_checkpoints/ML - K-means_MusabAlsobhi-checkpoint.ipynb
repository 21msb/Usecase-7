# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("final_data_msb.csv")

# %%
df.shape
# Out:
# (4506, 19)

# %%
df.head(2)
# Out:
#    Unnamed: 0               team              position  height   age  \
# 0           2  Manchester United            Goalkeeper   188.0  37.0
# 1           8  Manchester United  Defender Centre-Back   186.0  21.0
#
#    appearance  goals  assists  yellow cards  second yellow cards  red cards  \
# 0           4    0.0      0.0      0.000000                  0.0        0.0
# 1          34    0.0      0.0      0.130529                  0.0        0.0
#
#    goals conceded  clean sheets  minutes played  days_injured  games_injured  \
# 0        0.616438      0.924658             292           697             84
# 1        0.000000      0.000000            2758            47             13
#
#    award  current_value  highest_value
# 0      4         600000        6000000
# 1      0        2000000        2000000

# %%
df.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#                 team              position  height   age  appearance  goals  \
# 0  Manchester United            Goalkeeper   188.0  37.0           4    0.0
# 1  Manchester United  Defender Centre-Back   186.0  21.0          34    0.0
#
#    assists  yellow cards  second yellow cards  red cards  goals conceded  \
# 0      0.0      0.000000                  0.0        0.0        0.616438
# 1      0.0      0.130529                  0.0        0.0        0.000000
#
#    clean sheets  minutes played  days_injured  games_injured  award  \
# 0      0.924658             292           697             84      4
# 1      0.000000            2758            47             13      0
#
#    current_value  highest_value
# 0         600000        6000000
# 1        2000000        2000000

# %%
categorical_features = ['team', 'position']
numeric_features = ['height', 'age', 'appearance', 'goals', 'assists', 'yellow cards', 'second yellow cards', 'red cards', 
                    'goals conceded', 'clean sheets', 'minutes played', 'days_injured', 'games_injured', 'award', 'current_value', 
                    'highest_value']

# %%
df = pd.get_dummies(df, columns=categorical_features)

# %%
df.shape
# Out:
# (4506, 399)

# %%
# Elbow Method to find the optimal number of clusters
wcss = []
for i in range(1, 11):  # Checking for k from 1 to 10
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)  # WCSS

# Plotting the Elbow Method graph
plt.plot(range(1, 11), wcss, marker= 'o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (k)')
plt.ylabel('WCSS')
plt.show()

# %%
# Applying K-Means to the dataset with the optimal number of clusters
optimal_k = 3  # Replace with the optimal number determined by the elbow method
kmeans = KMeans(n_clusters=optimal_k)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
df['Cluster'] = kmeans.labels_

# %%
df.head(10)
# Out:
#    height   age  appearance     goals   assists  yellow cards  \
# 0   188.0  37.0           4  0.000000  0.000000      0.000000
# 1   186.0  21.0          34  0.000000  0.000000      0.130529
# 2   174.0  21.0          34  0.000000  0.087379      0.262136
# 3   189.0  33.0          31  0.000000  0.000000      0.064516
# 4   183.0  30.0           8  0.000000  0.000000      0.000000
# 5   190.0  21.0          17  0.000000  0.000000      0.000000
# 6   188.0  33.0          80  0.081032  0.027011      0.189076
# 7   180.0  20.0          46  0.110735  0.276838      0.083051
# 8   183.0  21.0          43  0.072727  0.072727      0.327273
# 9   179.0  23.0          32  0.223048  0.557621      0.334572
#
#    second yellow cards  red cards  goals conceded  clean sheets  ...  \
# 0             0.000000   0.000000        0.616438      0.924658  ...
# 1             0.000000   0.000000        0.000000      0.000000  ...
# 2             0.000000   0.000000        0.000000      0.000000  ...
# ...

# %%
plt.scatter(x=df['current_value'] , y=df['appearance'] , c=df['Cluster'])
plt.show()
